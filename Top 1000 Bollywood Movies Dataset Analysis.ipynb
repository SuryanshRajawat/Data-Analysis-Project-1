# %%
#Python Project On Top 1000 Bollywood Movies And Their Box Office
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#To watch the first five records
act=pd.read_csv("Top 1000 Bollywood Movies and their boxoffice.csv")
print(act.iloc[100:120])
# Out:
#      Unnamed: 0   SN                             Movie   Worldwide  \
# 100         100  101                      Bol Bachchan  1750000000
# 101         101  102                              Raid  1540000000
# 102         102  103                          2 States  1730000000
# 103         103  104                       Grand Masti  1450000000
# 104         104  105                            Race 2  1620000000
# 105         105  106                           Singham  1510000000
# 106         106  107                           Shivaay  1470000000
# 107         107  108                       Batla House  1270000000
# 108         108  109                              Zero  1780000000
# 109         109  110                      Welcome Back  1680000000
# 110         110  111                          Baaghi 3  1370000000
# 111         111  112                              Baby  1420000000
# 112         112  113  Manikarnika: The Queen of Jhansi  1420000000
# ...

# %%
#Looking the rows and columns of the dataset
act.shape
# Out:
# (1000, 9)

# %%
#for showing all row and columns
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   SN           1000 non-null   int64
#  2   Movie        1000 non-null   object
#  3   Worldwide    1000 non-null   int64
#  4   India Net    1000 non-null   int64
#  5   India Gross  1000 non-null   int64
#  6   Overseas     1000 non-null   int64
#  7   Budget       1000 non-null   int64
#  8   Verdict      1000 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 70.4+ KB

# %%
#for showing all row and columns
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   SN           1000 non-null   int64
#  2   Movie        1000 non-null   object
#  3   Worldwide    1000 non-null   int64
#  4   India Net    1000 non-null   int64
#  5   India Gross  1000 non-null   int64
#  6   Overseas     1000 non-null   int64
#  7   Budget       1000 non-null   int64
#  8   Verdict      1000 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 70.4+ KB

# %%
#To Know The Null Values Of Dataset
act.isnull()
# Out:
#      Unnamed: 0     SN  Movie  Worldwide  India Net  India Gross  Overseas  \
# 0         False  False  False      False      False        False     False
# 1         False  False  False      False      False        False     False
# 2         False  False  False      False      False        False     False
# 3         False  False  False      False      False        False     False
# 4         False  False  False      False      False        False     False
# ..          ...    ...    ...        ...        ...          ...       ...
# 995       False  False  False      False      False        False     False
# 996       False  False  False      False      False        False     False
# 997       False  False  False      False      False        False     False
# 998       False  False  False      False      False        False     False
# 999       False  False  False      False      False        False     False
#
#      Budget  Verdict
# 0     False    False
# 1     False    False
# ...

# %%
#it tells null values present or not in all columns
act.isnull().sum()
# Out:
# Unnamed: 0     0
# SN             0
# Movie          0
# Worldwide      0
# India Net      0
# India Gross    0
# Overseas       0
# Budget         0
# Verdict        0
# dtype: int64

# %%
#to know the duplicate values
act.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#to know the duplicate values as per column
act.duplicated().sum()
# Out:
# 0

# %%
#to know the duplicate values as per specific column
act["Movie"].duplicated().sum()
# Out:
# 6

# %%
#to drop duplicates from the column
print(act.drop_duplicates("Movie"))
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget               Verdict
# ...

# %%
act.iloc[90:100]
# Out:
#     Unnamed: 0   SN                       Movie   Worldwide   India Net  \
# 90          90   91          Bhaag Milkha Bhaag  1680000000  1080000000
# 91          91   92  Don 2: The Chase Continues  2100000000  1080000000
# 92          92   93                   Golmaal 3  1620000000  1060000000
# 93          93   94   Pushpa: The Rise (Part 1)  3500000000  1060000000
# 94          94   95                      ABCD 2  1660000000  1060000000
# 95          95   96                  Ek Villain  1550000000  1050000000
# 96          96   97              Son Of Sardaar  1500000000  1050000000
# 97          97   98                      Kaabil  1780000000  1040000000
# 98          98   99              De De Pyaar De  1390000000  1040000000
# 99          99  100                          83  1930000000  1040000000
#
#     India Gross   Overseas      Budget      Verdict
# 90   1460000000  210000000   300000000     SuperHit
# 91   1440000000  650000000   760000000          Hit
# ...

# %%
act.loc[(act["Budget"]==0),"Verdict"], "High Flop"
# Out:
# (887    All Time Blockbuster
#  933             Blockbuster
#  946    All Time Blockbuster
#  968             Blockbuster
#  976             Blockbuster
#  Name: Verdict, dtype: object,
#  'High Flop')

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   SN           1000 non-null   int64
#  2   Movie        1000 non-null   object
#  3   Worldwide    1000 non-null   int64
#  4   India Net    1000 non-null   int64
#  5   India Gross  1000 non-null   int64
#  6   Overseas     1000 non-null   int64
#  7   Budget       1000 non-null   int64
#  8   Verdict      1000 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 70.4+ KB

# %%
ver2=act["Verdict"]=act["Verdict"].replace(0,"Flop")
print(ver2)
# Out:
# 0      All Time Blockbuster
# 1      All Time Blockbuster
# 2      All Time Blockbuster
# 3      All Time Blockbuster
# 4      All Time Blockbuster
#                ...
# 995                       0
# 996                 Average
# 997                Disaster
# 998                       0
# 999                Disaster
# Name: Verdict, Length: 1000, dtype: object

# %%
act["Movie With Verdict"] = act["Movie"]+ " " + act["Verdict"]
print(act)
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget               Verdict  \
# ...

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1000 non-null   int64
#  1   SN                  1000 non-null   int64
#  2   Movie               1000 non-null   object
#  3   Worldwide           1000 non-null   int64
#  4   India Net           1000 non-null   int64
#  5   India Gross         1000 non-null   int64
#  6   Overseas            1000 non-null   int64
#  7   Budget              1000 non-null   int64
#  8   Verdict             1000 non-null   object
#  9   Movie With Verdict  1000 non-null   object
# dtypes: int64(7), object(3)
# memory usage: 78.3+ KB

# %%
act["Verdict"].isnull().iloc[990:997]
# Out:
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# 996    False
# Name: Verdict, dtype: bool

# %%
#To Addition India Worth And India Net That Store in India Worth New Column
act["India worth"]=act["India Net"] + act["India Gross"]
print(act)
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget               Verdict  \
# ...

# %%
#to summarize the data using group by function
gp=act.groupby(["Movie","Verdict"]).agg({"Movie":"count"})[0:10]
print(gp)
# Out:
#                                           Movie
# Movie               Verdict
# 102 Not Out         Hit                       1
# 1920                Average                   1
# 1920 - Evil Returns Above Average             1
# 1920 London         Below Average             1
# 1921                Above Average             1
# 2                   Average                   1
# 2 States            SuperHit                  1
# 3 Idiots            All Time Blockbuster      1
# 36 China Town       Above Average             1
# 7 Khoon Maaf        Flop                      1

# %%
#to change the datatype into to float, float to int etc...
act['Budget']=act['Budget'].astype('float')

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1000 non-null   int64
#  1   SN                  1000 non-null   int64
#  2   Movie               1000 non-null   object
#  3   Worldwide           1000 non-null   int64
#  4   India Net           1000 non-null   int64
#  5   India Gross         1000 non-null   int64
#  6   Overseas            1000 non-null   int64
#  7   Budget              1000 non-null   float64
#  8   Verdict             1000 non-null   object
#  9   Movie With Verdict  1000 non-null   object
#  10  India worth         1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
act['Budget']=act['Budget'].astype("int")

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1000 non-null   int64
#  1   SN                  1000 non-null   int64
#  2   Movie               1000 non-null   object
#  3   Worldwide           1000 non-null   int64
#  4   India Net           1000 non-null   int64
#  5   India Gross         1000 non-null   int64
#  6   Overseas            1000 non-null   int64
#  7   Budget              1000 non-null   int32
#  8   Verdict             1000 non-null   object
#  9   Movie With Verdict  1000 non-null   object
#  10  India worth         1000 non-null   int64
# dtypes: int32(1), int64(7), object(3)
# memory usage: 82.2+ KB

# %%
#for changing the name of SN column to Serial No., inplace is used for saving
act.rename(columns={"SN":"Serial No."},inplace=True)
act.head(50)
# Out:
#     Unnamed: 0  Serial No.                        Movie    Worldwide  \
# 0            0           1                      Pathaan  10500000000
# 1            1           2   Baahubali 2 The Conclusion  17880000000
# 2            2           3                KGF Chapter 2  12080000000
# 3            3           4                       Dangal  20700000000
# 4            4           5                        Sanju   5880000000
# 5            5           6                           PK   7920000000
# 6            6           7              Tiger Zinda Hai   5580000000
# 7            7           8            Bajrangi Bhaijaan   9220000000
# 8            8           9                          War   4710000000
# 9            9          10                    Padmaavat   5850000000
# 10          10          11                       Sultan   6270000000
# 11          11          12                  Kabir Singh   3770000000
# 12          12          13  Tanhaji: The Unsung Warrior   3610000000
# ...

# %%
#for describing the specific columns
act[["India Net","India Gross","Budget"]].describe()
# Out:
#           India Net   India Gross        Budget
# count  1.000000e+03  1.000000e+03  1.000000e+03
# mean   4.079600e+08  6.126900e+08  2.285455e+08
# std    5.783055e+08  9.814085e+08  5.357887e+08
# min    2.000000e+07  0.000000e+00 -2.147484e+09
# 25%    9.000000e+07  1.400000e+08  8.000000e+07
# 50%    2.000000e+08  3.100000e+08  2.000000e+08
# 75%    4.600000e+08  6.825000e+08  3.800000e+08
# max    5.240000e+09  1.416000e+10  2.100000e+09

# %%
act[["Verdict"]].describe()
# Out:
#        Verdict
# count     1000
# unique      10
# top       Flop
# freq       197

# %%
act.columns
# Out:
# Index(['Unnamed: 0', 'Serial No.', 'Movie', 'Worldwide', 'India Net',
#        'India Gross', 'Overseas', 'Budget', 'Verdict', 'Movie With Verdict',
#        'India worth'],
#       dtype='object')

# %%
act["Budget"].describe()
# Out:
# count    1.000000e+03
# mean     2.285455e+08
# std      5.357887e+08
# min     -2.147484e+09
# 25%      8.000000e+07
# 50%      2.000000e+08
# 75%      3.800000e+08
# max      2.100000e+09
# Name: Budget, dtype: float64

# %%
#Removing Negative Value From Budget Column
act=act[(act["Budget"]>=0)]

# %%
act.head(50)
# Out:
#     Unnamed: 0  Serial No.                        Movie    Worldwide  \
# 2            2           3                KGF Chapter 2  12080000000
# 3            3           4                       Dangal  20700000000
# 4            4           5                        Sanju   5880000000
# 5            5           6                           PK   7920000000
# 6            6           7              Tiger Zinda Hai   5580000000
# 7            7           8            Bajrangi Bhaijaan   9220000000
# 8            8           9                          War   4710000000
# 10          10          11                       Sultan   6270000000
# 11          11          12                  Kabir Singh   3770000000
# 12          12          13  Tanhaji: The Unsung Warrior   3610000000
# 14          14          15                      Dhoom 3   5580000000
# 15          15          16            The Kashmir Files   3410000000
# 17          17          18      URI The Surgical Strike   3410000000
# ...

# %%
#Getting the frequency of Verdict Column
act["Verdict"].value_counts()
# Out:
# Verdict
# Flop                    196
# Hit                     188
# Average                 131
# SuperHit                112
# Disaster                 81
# Blockbuster              71
# Below Average            66
# Above Average            55
# 0                        44
# All Time Blockbuster     26
# Name: count, dtype: int64

# %%
#Getting the frequency of Verdict Column Top 10
act['Verdict'].value_counts()[0:5]
# Out:
# Verdict
# Flop        196
# Hit         188
# Average     131
# SuperHit    112
# Disaster     81
# Name: count, dtype: int64

# %%
#ploting the 5 verdict countplot chart with values in graph or say labels=values her 1st half upto comma "," is for keys/Names and after comma it is for values
plt.figure(figsize=(8,5))
plt.title("VERDICT BAR GRAPH")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.bar(act["Verdict"].value_counts()[0:5].keys(),(act["Verdict"].value_counts()[0:5]),color=["blue","red","yellow","brown","green"])
plt.show()

# %%
#For Showing Counts Of India Net
act["India Net"].value_counts()[0:15]
# Out:
# India Net
# 100000000    36
# 50000000     35
# 20000000     34
# 30000000     33
# 60000000     33
# 70000000     32
# 80000000     31
# 110000000    28
# 40000000     27
# 150000000    25
# 200000000    25
# 170000000    24
# 130000000    23
# 120000000    22
# 90000000     21
# Name: count, dtype: int64

# %%
#histogram of India Net Column
plt.figure(figsize=(8,5))
plt.title("INDIA NET HISTOGRAM")
plt.xlabel("India Net")
plt.ylabel("Frequency")
plt.hist(act["India Net"][0:15],bins=10,color="SkyBlue")
plt.show()

# %%
act["Verdict"].value_counts()
# Out:
# Verdict
# Flop                    196
# Hit                     188
# Average                 131
# SuperHit                112
# Disaster                 81
# Blockbuster              71
# Below Average            66
# Above Average            55
# 0                        44
# All Time Blockbuster     26
# Name: count, dtype: int64

# %%
#histogram of India Net Column
ver=act[["Movie","India Gross"]][0:11]
print(ver)
# Out:
#                           Movie  India Gross
# 2                 KGF Chapter 2  10000000000
# 3                        Dangal   5350000000
# 4                         Sanju   4380000000
# 5                            PK   4890000000
# 6               Tiger Zinda Hai   4330000000
# 7             Bajrangi Bhaijaan   4320000000
# 8                           War   3750000000
# 10                       Sultan   4210000000
# 11                  Kabir Singh   3300000000
# 12  Tanhaji: The Unsung Warrior   3250000000
# 14                      Dhoom 3   3720000000

# %%
plt.figure(figsize=(8,5))
plt.title("MOVIE + INDIA NET HISTOGRAM")
plt.xlabel("India Net")
plt.ylabel("Frequency")
plt.hist(act["India Net"],bins=10,color="yellow")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("MOVIE + INDIA GROSS HISTOGRAM")
plt.xlabel("India Gross")
plt.ylabel("Frequency")
plt.bar(list(ver["Movie"][0:5]),list(ver["India Gross"])[0:5],color=["blue","red","yellow","brown","green"])
# Out:
# <BarContainer object of 5 artists>

# %%
#to check following movie present in the column or not
#here true in war means war is present
ver["Movie"]=="War"[0:100]
# Out:
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 10    False
# 11    False
# 12    False
# 14    False
# Name: Movie, dtype: bool

# %%
#Dropping War From The List
ver.drop(8,inplace=True)

# %%
#To Print The Updated List
#Output=False Means War is Dropped
ver=["Movie"]=="War"[0:100]
ver
# Out:
# False

# %%
total=act[["Movie","India worth"]]
total.head(10)
# Out:
#                           Movie  India worth
# 2                 KGF Chapter 2  14350000000
# 3                        Dangal   9090000000
# 4                         Sanju   7800000000
# 5                            PK   8290000000
# 6               Tiger Zinda Hai   7720000000
# 7             Bajrangi Bhaijaan   7520000000
# 8                           War   6780000000
# 10                       Sultan   7210000000
# 11                  Kabir Singh   6080000000
# 12  Tanhaji: The Unsung Warrior   6020000000

# %%
#To Print Top 5 Movie With India Worth Graph
plt.figure(figsize=(5,5))
plt.title("MOVIE + INDIA WORTH BAR GRAPH")
plt.xlabel("Movie X Axis")
plt.ylabel("Frequency")
plt.bar(list(total["Movie"][0:5]),list(total["India worth"])[0:5],color=["blue","red","green","brown","yellow"])
plt.show()

# %%
#top 10 movies With India Total Worth Or Earning On India Basis
india_ttl=total.head(10)
india_ttl
# Out:
#                           Movie  India worth
# 2                 KGF Chapter 2  14350000000
# 3                        Dangal   9090000000
# 4                         Sanju   7800000000
# 5                            PK   8290000000
# 6               Tiger Zinda Hai   7720000000
# 7             Bajrangi Bhaijaan   7520000000
# 8                           War   6780000000
# 10                       Sultan   7210000000
# 11                  Kabir Singh   6080000000
# 12  Tanhaji: The Unsung Warrior   6020000000

# %%
#Plotting Pie Chart Of Top 10 Movies With Total India Worth Or Total Earning from startangle 90 digree from 1 to 10 in order
plt.title("TOTAL INDIA WORTH WITH MOVIE PIE CHART")
plt.pie(india_ttl["India worth"],labels=india_ttl["Movie"],autopct="%0.1f%%",startangle=90)
plt.show()

# %%
#To Concatinate New "Movie With Verdict Column"
ver=act[["Movie","India worth","Movie With Verdict"]]
per=ver.head(10)
per
# Out:
#                           Movie  India worth  \
# 2                 KGF Chapter 2  14350000000
# 3                        Dangal   9090000000
# 4                         Sanju   7800000000
# 5                            PK   8290000000
# 6               Tiger Zinda Hai   7720000000
# 7             Bajrangi Bhaijaan   7520000000
# 8                           War   6780000000
# 10                       Sultan   7210000000
# 11                  Kabir Singh   6080000000
# 12  Tanhaji: The Unsung Warrior   6020000000
#
#                          Movie With Verdict
# 2        KGF Chapter 2 All Time Blockbuster
# 3               Dangal All Time Blockbuster
# 4                Sanju All Time Blockbuster
# 5                   PK All Time Blockbuster
# 6               Tiger Zinda Hai Blockbuster
# 7    Bajrangi Bhaijaan All Time Blockbuster
# 8                           War Blockbuster
# 10                       Sultan Blockbuster
# 11         Kabir Singh All Time Blockbuster
# ...

# %%
#Plotting Pie Chart Of Top 10 Movies With Total India Worth Or Total Earning from startangle 90 digree from 1 to 10 in order
plt.title("INDIA WORTH AND MOVIE WITH VERDICT")
plt.pie(per["India worth"],labels=per["Movie With Verdict"],autopct="%0.1f%%",startangle=90)
plt.show()

# %%
#Doughnut Chart Of India Worth And Movies
plt.pie(per["India worth"],labels=per["Movie"],radius=2,autopct="%0.1f%%")
plt.pie([1],colors=["white"],radius=1)
plt.show()

# %%
#Doughnut Chart Of India Worth And Movie With Verdict
plt.pie(per["India worth"],labels=per["Movie With Verdict"],radius=2,autopct="%0.1f%%")
plt.pie([1],colors=["white"],radius=1)
plt.show()

# %%
#To Plot The Scatter Plot With Grids Of Top 5 Movies
plt.grid(True)
plt.scatter(ver["Movie"][0:5],list(ver["India worth"])[0:5],marker="*")
plt.show()

# %%
#SeabornGraph Bar Graph
plt.title("VERDICT BAR GRAPH")
plot=sns.countplot(x="Verdict",data=act,hue="Verdict",order=act["Verdict"].value_counts().nlargest(5).index, palette="Set1",legend=False)

#For Printing Values Only Contains In Seaborn
for bars in plot.containers:
    plt.bar_label(bars)
    
plt.show()

# %%
#Plotting Scatter Graph Seaborn
plt.title("SCATTER PLOT")
sns.scatterplot(x="India Gross",y="India worth",data=act)
plt.show()

# %%
#END OF PROJECT THE DATAA THAT WE USED!!!
act.head(10)
# Out:
#     Unnamed: 0  Serial No.                        Movie    Worldwide  \
# 2            2           3                KGF Chapter 2  12080000000
# 3            3           4                       Dangal  20700000000
# 4            4           5                        Sanju   5880000000
# 5            5           6                           PK   7920000000
# 6            6           7              Tiger Zinda Hai   5580000000
# 7            7           8            Bajrangi Bhaijaan   9220000000
# 8            8           9                          War   4710000000
# 10          10          11                       Sultan   6270000000
# 11          11          12                  Kabir Singh   3770000000
# 12          12          13  Tanhaji: The Unsung Warrior   3610000000
#
#      India Net  India Gross     Overseas      Budget               Verdict  \
# 2   4350000000  10000000000   2070000000  1000000000  All Time Blockbuster
# ...
